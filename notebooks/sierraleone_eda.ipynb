# %%
#import libraries we want to use to make the EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data
filePath = "../data/sierraleone-bumbuna.csv"
df = pd.read_csv(filePath)
df.head()
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1  2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2  2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3  2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4  2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#    WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 1      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 2      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 3      0.0  0.0      0.0  1002         0            0.1   22.3   22.6
# 4      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
#get statistical data for the whole data
df.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# ...

# %%
#each columns non-null value and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525600 entries, 0 to 525599
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Timestamp      525600 non-null  object
#  1   GHI            525600 non-null  float64
#  2   DNI            525600 non-null  float64
#  3   DHI            525600 non-null  float64
#  4   ModA           525600 non-null  float64
#  5   ModB           525600 non-null  float64
#  6   Tamb           525600 non-null  float64
#  7   RH             525600 non-null  float64
#  8   WS             525600 non-null  float64
#  9   WSgust         525600 non-null  float64
#  10  WSstdev        525600 non-null  float64
#  11  WD             525600 non-null  float64
#  12  WDstdev        525600 non-null  float64
#  13  BP             525600 non-null  int64
#  14  Cleaning       525600 non-null  int64
#  15  Precipitation  525600 non-null  float64
# ...

# %%
#number of null in every column
df.isna().sum()
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
#compute missing ration
df.isna().mean().sort_values(ascending=False)
# Out:
# Comments         1.0
# GHI              0.0
# Timestamp        0.0
# DNI              0.0
# DHI              0.0
# ModB             0.0
# ModA             0.0
# RH               0.0
# WS               0.0
# WSgust           0.0
# Tamb             0.0
# WSstdev          0.0
# WD               0.0
# BP               0.0
# WDstdev          0.0
# Cleaning         0.0
# Precipitation    0.0
# TModA            0.0
# TModB            0.0
# dtype: float64

# %%
from scipy.stats import zscore

colsToCheck = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']

zScores = df[colsToCheck].apply(zscore)
zScores
# Out:
#              GHI       DNI       DHI      ModA      ModB        WS    WSgust
# 0      -0.678931 -0.532701 -0.720500 -0.686758 -0.685782 -0.924846 -1.046105
# 1      -0.678931 -0.532701 -0.720500 -0.686758 -0.685782 -0.924846 -1.046105
# 2      -0.678931 -0.532701 -0.720500 -0.686758 -0.685782 -0.924846 -1.046105
# 3      -0.678931 -0.532243 -0.720500 -0.686758 -0.685782 -0.924846 -1.046105
# 4      -0.678931 -0.532701 -0.720500 -0.686758 -0.685782 -0.924846 -1.046105
# ...          ...       ...       ...       ...       ...       ...       ...
# 525595 -0.681946 -0.532701 -0.733712 -0.686758 -0.685782 -0.924846 -1.046105
# 525596 -0.682281 -0.532701 -0.734342 -0.686758 -0.685782 -0.924846 -1.046105
# 525597 -0.682281 -0.532701 -0.734971 -0.686758 -0.685782 -0.924846 -1.046105
# 525598 -0.682281 -0.533158 -0.736229 -0.686758 -0.685782 -0.924846 -1.046105
# 525599 -0.682281 -0.532701 -0.736858 -0.686758 -0.685782 -0.924846 -1.046105
#
# [525600 rows x 7 columns]

# %%
#outlier
outliers = (zScores.abs() > 3).sum()
outliers
# Out:
# GHI       2477
# DNI       7586
# DHI       2986
# ModA      1604
# ModB      2041
# WS        3967
# WSgust    3665
# dtype: int64

# %%
mask = (zScores.abs() < 3).all(axis = 1)
dfClean = df[mask]
dfClean.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  509308.000000  509308.000000  509308.000000  509308.000000
# mean      185.000024     104.128943     108.104278     189.764194
# std       279.019460     200.954182     153.691835     281.888942
# min       -15.900000      -7.800000     -16.700000       0.000000
# 25%        -3.300000      -0.300000      -4.100000       0.000000
# 50%        -0.400000      -0.100000      -0.600000       1.200000
# 75%       331.300000      74.800000     217.900000     327.200000
# max      1097.000000     772.300000     590.500000    1105.000000
#
#                 ModB           Tamb             RH             WS  \
# count  509308.000000  509308.000000  509308.000000  509308.000000
# mean      181.693908      26.214248      79.747674       1.089871
# std       269.988109       4.397260      20.556188       1.155220
# min         0.000000      12.300000       9.900000       0.000000
# ...

# %%
#save the clean data
dfClean.to_csv("../data/sierraleone_clean.csv")

# %%
df = dfClean.copy()

df['Timestamp'] = pd.to_datetime(df['Timestamp'])

plt.figure(figsize=(12, 6))
plt.plot(df['Timestamp'], df['GHI'], label='GHI')
plt.plot(df['Timestamp'], df['DNI'], label='DNI')
plt.plot(df['Timestamp'], df['DHI'], label='DHI')
plt.legend()
plt.title('Solar Irradiance Over Time')
# Out:
# Text(0.5, 1.0, 'Solar Irradiance Over Time')
# c:\Users\hp\Desktop\Projects\ML\KAIM\Week-0\Solar-challenge-week1\env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# c:\Users\hp\Desktop\Projects\ML\KAIM\Week-0\Solar-challenge-week1\env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#seasonally
df_season = df.copy()
df_season['month'] = df_season['Timestamp'].dt.month
df_season.groupby('month')[['GHI', 'DNI', 'DHI']].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
#daily
df_daily = df.copy()
df_daily['hour'] = df_daily['Timestamp'].dt.hour
df_daily.groupby('hour')[['GHI', 'DNI', 'DHI']].mean().plot()
# Out:
# <Axes: xlabel='hour'>

# %%
df.groupby('Cleaning')[['ModA', 'ModB']].mean()
# Out:
#                 ModA       ModB
# Cleaning
# 0         232.323881  224.95509
# 1         306.610124  301.45000

# %%
df.groupby('Cleaning')[['ModA', 'ModB']].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Cleaning'>

# %%
features = ['GHI', 'DNI', 'DHI', 'TModA', 'TModB']
#correlation
sns.heatmap(df[features].corr(), annot=True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x='WS', y='GHI')
# Out:
# <Axes: xlabel='WS', ylabel='GHI'>

# %%
sns.scatterplot(data=df, x='WD', y='GHI')
# Out:
# <Axes: xlabel='WD', ylabel='GHI'>

# %%
sns.scatterplot(data=df, x='RH', y='Tamb')
# Out:
# <Axes: xlabel='RH', ylabel='Tamb'>

# %%
sns.scatterplot(data=df, x='RH', y='GHI')
# Out:
# <Axes: xlabel='RH', ylabel='GHI'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['WD'], bins=36, kde=True)
plt.title('Wind Direction Distribution')
# Out:
# Text(0.5, 1.0, 'Wind Direction Distribution')

# %%
df['GHI'].hist(bins=50)
# Out:
# <Axes: >

# %%
df['WS'].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['Tamb'], df['GHI'], s=df['RH']*2, alpha=0.5)
plt.xlabel('Ambient Temperature (°C)')
plt.ylabel('Global Horizontal Irradiance (W/m²)')
plt.title('GHI vs. Ambient Temperature (Bubble size = RH)')
#higher temp, higher GHI
#also at high temp alot of bubbles gather rather than in humidity
# Out:
# Text(0.5, 1.0, 'GHI vs. Ambient Temperature (Bubble size = RH)')
